# %%
import cv2
import numpy as np
from glob import glob
import os
from matplotlib import pyplot as plt

# %%
# 0--Parade/0_Parade_marchingband_1_849.jpg
f1 = [449, 330, 122, 149, 488.906, 373.643, 0.0, 542.089, 376.442, 0.0, 515.031, 412.83, 0.0, 485.174, 425.893, 0.0, 538.357, 431.491, 0.0, 0.82]  
# 0--Parade/0_Parade_Parade_0_904.jpg
f2 = [361, 98, 263, 339, 424.143, 251.656, 0.0, 547.134, 232.571, 0.0, 494.121, 325.875, 0.0, 453.83, 368.286, 0.0, 561.978, 342.839, 0.0, 0.89]

# %%
print(len(f1))
print(len(f2))
# Out:
# 20
# 20

# %%
#os.listdir('dataset/widerface/train/images')

# %%
img1 = cv2.imread("dataset/widerface/train/images/0--Parade/0_Parade_marchingband_1_849.jpg", cv2.IMREAD_COLOR)
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)

# %%
center1 = (int(f1[4]),int(f1[5]))
center2 = (int(f1[7]),int(f1[8]))
center3 = (int(f1[10]),int(f1[11]))
center4 = (int(f1[13]),int(f1[14]))
center5 = (int(f1[16]),int(f1[17]))

cv2.circle(img1, center1, 10, (0,0,255), -1)
cv2.circle(img1, center2, 10, (0,0,255), -1)
cv2.circle(img1, center3, 10, (0,0,255), -1)
cv2.circle(img1, center4, 10, (0,0,255), -1)
cv2.circle(img1, center5, 10, (0,0,255), -1)
# Out:
# array([[[237, 251, 255],
#         [237, 251, 255],
#         [237, 251, 255],
#         ...,
#         [248, 250, 247],
#         [255, 255, 248],
#         [243, 244, 230]],
#
#        [[ 59,  72, 106],
#         [ 59,  72, 106],
#         [ 59,  72, 106],
#         ...,
#         [168, 169, 171],
#         [249, 250, 244],
#         [255, 255, 245]],
#
#        [[ 37,  50,  92],
#         [ 37,  50,  92],
#         [ 37,  50,  92],
#         ...,
#         [162, 162, 170],
#         [255, 255, 255],
#         [255, 255, 251]],
#
#        ...,
#
#        [[ 67,  73,  35],
#         [ 66,  72,  34],
#         [ 64,  70,  32],
#         ...,
#         [156, 156, 146],
#         [255, 254, 249],
#         [254, 253, 249]],
#
#        [[ 74,  80,  42],
#         [ 72,  78,  40],
#         [ 68,  74,  36],
#         ...,
#         [156, 156, 146],
#         [255, 254, 249],
#         [254, 253, 249]],
#
#        [[ 72,  78,  40],
#         [ 70,  76,  38],
#         [ 67,  73,  35],
# ...

# %%
img1.shape
# Out:
# (1385, 1024, 3)

# %%
plt.figure(figsize=(25,15))
plt.imshow(img1)
plt.show()
#cv2.imshow('img1', img1)
#cv2.waitKey(0)
#cv2.destroyAllWindows()

# %%
img2 = cv2.imread("dataset/widerface/train/images/0--Parade/0_Parade_Parade_0_904.jpg", cv2.IMREAD_COLOR)
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

# %%
center1 = (int(f2[4]),int(f2[5]))
center2 = (int(f2[7]),int(f2[8]))
center3 = (int(f2[10]),int(f2[11]))
center4 = (int(f2[13]),int(f2[14]))
center5 = (int(f2[16]),int(f2[17]))

cv2.circle(img2, center1, 10, (0,0,255), -1)
cv2.circle(img2, center2, 10, (0,0,255), -1)
cv2.circle(img2, center3, 10, (0,0,255), -1)
cv2.circle(img2, center4, 10, (0,0,255), -1)
cv2.circle(img2, center5, 10, (0,0,255), -1)
# Out:
# array([[[ 78,  85, 101],
#         [ 76,  83,  99],
#         [ 73,  82,  97],
#         ...,
#         [ 43,  54,  82],
#         [ 43,  59,  85],
#         [ 36,  56,  83]],
#
#        [[ 89,  96, 112],
#         [ 87,  94, 110],
#         [ 86,  93, 109],
#         ...,
#         [ 47,  57,  84],
#         [ 47,  63,  89],
#         [ 41,  58,  84]],
#
#        [[103, 107, 119],
#         [100, 106, 120],
#         [ 99, 105, 119],
#         ...,
#         [ 54,  61,  87],
#         [ 55,  67,  93],
#         [ 48,  64,  89]],
#
#        ...,
#
#        [[ 80,  83,  88],
#         [ 80,  83,  88],
#         [ 81,  82,  87],
#         ...,
#         [105, 128, 134],
#         [105, 125, 132],
#         [104, 124, 131]],
#
#        [[ 81,  84,  89],
#         [ 80,  83,  88],
#         [ 82,  83,  88],
#         ...,
#         [122, 143, 148],
#         [122, 141, 147],
#         [121, 140, 146]],
#
#        [[ 81,  84,  89],
#         [ 81,  84,  89],
#         [ 83,  84,  89],
# ...

# %%
plt.figure(figsize=(25,15))
plt.imshow(img2)
plt.show()
#cv2.imshow('img1', img1)
#cv2.waitKey(0)
#cv2.destroyAllWindows()
